# %%
# !pip install diffusers 
# !pip install -U peft 

from diffusers import FluxPipeline
import torch

# Load the base model (schnell) from Hugging Face
pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-schnell",
    torch_dtype=torch.bfloat16,
    # device_map="auto"  # or specify device
)
pipe.enable_model_cpu_offload()

# Now you can run inference
prompt = "A futuristic cityscape with flying cars"
img = pipe(prompt, guidance_scale=1.0, num_inference_steps=4).images[0]
img.save("output.png")
# Out:
# Looking in indexes: https://pypi.org/simple, https://europe-west3-python.pkg.dev/rasa-releases/rasa-plus-py/simple/
# Requirement already satisfied: diffusers in /opt/homebrew/anaconda3/lib/python3.11/site-packages (0.35.1)
# Requirement already satisfied: importlib_metadata in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (6.0.0)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (0.35.3)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (2023.12.25)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from diffusers) (11.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (1.1.10)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from importlib_metadata->diffusers) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->diffusers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->diffusers) (2023.7.22)
# Looking in indexes: https://pypi.org/simple, https://europe-west3-python.pkg.dev/rasa-releases/rasa-plus-py/simple/
# Requirement already satisfied: peft in /opt/homebrew/anaconda3/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (23.1)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (5.9.0)
# Requirement already satisfied: pyyaml in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (6.0)
# Requirement already satisfied: torch>=1.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (2.6.0)
# Requirement already satisfied: transformers in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (4.51.2)
# Requirement already satisfied: tqdm in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (4.65.0)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (1.6.0)
# Requirement already satisfied: safetensors in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from peft) (0.35.3)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2025.3.2)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface_hub>=0.25.0->peft) (1.1.10)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from transformers->peft) (2023.12.25)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from transformers->peft) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2023.7.22)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
